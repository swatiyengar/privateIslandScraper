# %% [markdown]
# # Private Island Scraper
#
# Don't we all day dream about having "Bezos" money? Or at minimum, "David Schwimmer" money? I certainly do...and maybe I'd throw a few 'pennies' down on a private island.
#
# This scraper will tell me the list prices for private islands for sale every week based on the listings found in [Private Islands, Inc](https://www.privateislandsonline.com/search?availability=sale)

# %% [markdown]
# Elements of the Private Island Database include:
# - Name (class_ = "name")
# - Image (class_ = "img-container")
# - Acreage (class_ = "num")
# - Price in USD (class_ = "list-price")
# - Country (class_ = "list-name" a href = )
# - Continent (class_ = "list-name" a href = )
# - Type of Development
# - Type of Island
# - Type of Lifestyle
# - Tag list (class_ = "tags tags--listing")

# %%
# import libraries

import requests
from bs4 import BeautifulSoup
import pandas as pd
from io import StringIO
import numpy as np

# %%
response = requests.get("https://www.privateislandsonline.com/search?availability=sale")
doc = BeautifulSoup(response.text, 'html.parser')

# %%
doc = BeautifulSoup(response.text, 'html.parser')

# %%
island_names = doc.select('.name')
for name in island_names:
    print(name.text.strip())
# Out:
# Island of Patroklos
# Rangyai Island
# Blackbook Listing
# (2867)
# Pumpkin Key
# Long Caye Private Island
# Ifuru Resort with Airport and Funadhoo Island
# Spectabilis Island
# Cave Cay
# Schulzewerder Island

# %%
island_images = doc.select('.islandImageWithoutBg')
for image in island_images:
    print(image.get('src'))
# Out:
# https://www.privateislandsonline.com/uploads/resize/_885_5880dcf91ffc0.jpg-1074-822.jpg
# https://www.privateislandsonline.com/uploads/resize/_597_image_fe02c338d8.jpg-1074-822.jpg
# None
# https://www.privateislandsonline.com/uploads/resize/_1682_60f97f2079fda.jpg-1074-822.jpg
# https://www.privateislandsonline.com/uploads/resize/_2551_5c41c9b0cd95b.JPG-1074-822.JPG
# https://www.privateislandsonline.com/uploads/resize/_2793_5ebb001ab79fb.jpg-1074-822.jpg
# https://www.privateislandsonline.com/uploads/resize/_1747_image_691ba69c7d.jpg-1074-822.jpg
# https://www.privateislandsonline.com/uploads/resize/_909_6026d75621ccf.jpg-1074-822.jpg
# https://www.privateislandsonline.com/uploads/resize/_839_image_2555ca35dc.jpg-1074-822.jpg

# %%
island_acreage = doc.select('.num')
for acreage in island_acreage:
    print(acreage.text.strip())
# Out:
# 643
# 110
# 100 - 200
# 26
# 40
# 169
# 460
# 220
# 21

# %%
island_price = doc.select('.list-price')
for price in island_price:
    print(price.text.strip())
# Out:
# $
# Price Upon Request
# $
# 160,000,000.00
# $
# Price Upon Request
# $
# 95,000,000.00
# $
# Price Upon Request
# $
# 65,000,000.00
# $
# 62,000,000.00
# $
# 60,000,000.00
# $
# Price Upon Request

# %%
island_region = doc.select('.list-name')
for region in island_region:
    print(region.text.strip())
# Out:
# Greece
# , Europe
# Thailand
# , Asia
# Spain
# , Europe
# Florida
# , United States
# Belize
# , Central America
# Maldives
# , Asia
# The Exumas
# , Bahamas
# , Caribbean
# The Exumas
# , Bahamas
# , Caribbean
# Poland
# , Europe

# %%
island_tags = doc.select(".tags--listing")
for tag in island_tags:
    print(tag.text.strip())
    print(type(tag))
# Out:
# Large AcreageOcean IslandIncome PotentialMainland Power
# <class 'bs4.element.Tag'>
# Islands with BeachesLarge AcreageOcean IslandIncome Potential
# <class 'bs4.element.Tag'>
# Large AcreageOcean IslandTurn KeyIncome Potential
# <class 'bs4.element.Tag'>
# Large AcreageOcean IslandTurn KeyIncome Potential
# <class 'bs4.element.Tag'>
# Large AcreageOcean IslandTurn KeyIncome Potential
# <class 'bs4.element.Tag'>
# Islands with BeachesAirstrip or Fly-inLarge AcreageOcean IslandTurn KeyIncome Potential
# <class 'bs4.element.Tag'>
# Islands with BeachesLarge AcreageOcean IslandIncome Potential
# <class 'bs4.element.Tag'>
# Islands with BeachesLarge AcreageOcean IslandTurn KeyIncome Potential
# <class 'bs4.element.Tag'>
# Large AcreageIncome ProducingLake IslandSeasonalTurn KeyHistoricIncome Potential
# <class 'bs4.element.Tag'>

# %%
import re

def clean_table(x):
    x = x.replace("\n", "").strip()
    x = x.replace('$', "")
    return x

# %%
response = requests.get("https://www.privateislandsonline.com/search?availability=sale")
doc = BeautifulSoup(response.text, 'html.parser')

islands = doc.select('.grid')


rows = []

for island in islands:
    print('-----')
    row = {}
    
    row['name'] = island.select_one('.name').text.strip()
    try:
        row['image'] = island.select_one('.islandImageWithoutBg')['src']
    except:
        print('No image link')
    
    try:
        row['acreage'] = island.select_one('.num').text.strip()
    except:
        print('No acreage')

    try:
        row['price'] = clean_table(island.select_one('.list-price').text.strip())
    except:
        print('No price')
    
    try:
        row['region'] = clean_table(island.select_one('.list-name').text.strip())
    except:
        print('No region data')
        
    try:
        row['tags'] = clean_table(island.select_one(".tags--listing").text.strip())
    except: 
        print('No tags')
    

    
    print(row)
    rows.append(row)
# Out:
# -----
# {'name': 'Island of Patroklos', 'image': 'https://www.privateislandsonline.com/uploads/resize/_885_5880dcf91ffc0.jpg-1074-822.jpg', 'acreage': '643', 'price': ' Price Upon Request', 'region': 'Greece, Europe', 'tags': 'Large AcreageOcean IslandIncome PotentialMainland Power'}
# -----
# {'name': 'Rangyai Island', 'image': 'https://www.privateislandsonline.com/uploads/resize/_597_image_fe02c338d8.jpg-1074-822.jpg', 'acreage': '110', 'price': '160,000,000.00', 'region': 'Thailand, Asia', 'tags': 'Islands with BeachesLarge AcreageOcean IslandIncome Potential'}
# -----
# No image link
# {'name': 'Blackbook Listing\n(2867)', 'acreage': '100 - 200', 'price': ' Price Upon Request', 'region': 'Spain, Europe', 'tags': 'Large AcreageOcean IslandTurn KeyIncome Potential'}
# -----
# {'name': 'Pumpkin Key', 'image': 'https://www.privateislandsonline.com/uploads/resize/_1682_60f97f2079fda.jpg-1074-822.jpg', 'acreage': '26', 'price': '95,000,000.00', 'region': 'Florida, United States', 'tags': 'Large AcreageOcean IslandTurn KeyIncome Potential'}
# -----
# {'name': 'Long Caye Private Island', 'image': 'https://www.privateislandsonline.com/uploads/resize/_2551_5c41c9b0cd95b.JPG-1074-822.JPG', 'acreage': '40', 'price': ' Price Upon Request', 'region': 'Belize, Central America', 'tags': 'Large AcreageOcean IslandTurn KeyIncome Potential'}
# -----
# {'name': 'Ifuru Resort with Airport and Funadhoo Island', 'image': 'https://www.privateislandsonline.com/uploads/resize/_2793_5ebb001ab79fb.jpg-1074-822.jpg', 'acreage': '169', 'price': '65,000,000.00', 'region': 'Maldives, Asia', 'tags': 'Islands with BeachesAirstrip or Fly-inLarge AcreageOcean IslandTurn KeyIncome Potential'}
# -----
# {'name': 'Spectabilis Island', 'image': 'https://www.privateislandsonline.com/uploads/resize/_1747_image_691ba69c7d.jpg-1074-822.jpg', 'acreage': '460', 'price': '62,000,000.00', 'region': 'The Exumas, Bahamas, Caribbean', 'tags': 'Islands with BeachesLarge AcreageOcean IslandIncome Potential'}
# -----
# {'name': 'Cave Cay', 'image': 'https://www.privateislandsonline.com/uploads/resize/_909_6026d75621ccf.jpg-1074-822.jpg', 'acreage': '220', 'price': '60,000,000.00', 'region': 'The Exumas, Bahamas, Caribbean', 'tags': 'Islands with BeachesLarge AcreageOcean IslandTurn KeyIncome Potential'}
# -----
# {'name': 'Schulzewerder Island', 'image': 'https://www.privateislandsonline.com/uploads/resize/_839_image_2555ca35dc.jpg-1074-822.jpg', 'acreage': '21', 'price': ' Price Upon Request', 'region': 'Poland, Europe', 'tags': 'Large AcreageIncome ProducingLake IslandSeasonalTurn KeyHistoricIncome Potential'}

# %%
island_df = pd.DataFrame(rows)
island_df
# Out:
#                                             name  \
# 0                            Island of Patroklos
# 1                                 Rangyai Island
# 2                      Blackbook Listing\n(2867)
# 3                                    Pumpkin Key
# 4                       Long Caye Private Island
# 5  Ifuru Resort with Airport and Funadhoo Island
# 6                             Spectabilis Island
# 7                                       Cave Cay
# 8                           Schulzewerder Island
#
#                                                image    acreage  \
# 0  https://www.privateislandsonline.com/uploads/r...        643
# 1  https://www.privateislandsonline.com/uploads/r...        110
# 2                                                NaN  100 - 200
# 3  https://www.privateislandsonline.com/uploads/r...         26
# 4  https://www.privateislandsonline.com/uploads/r...         40
# 5  https://www.privateislandsonline.com/uploads/r...        169
# 6  https://www.privateislandsonline.com/uploads/r...        460
# 7  https://www.privateislandsonline.com/uploads/r...        220
# 8  https://www.privateislandsonline.com/uploads/r...         21
#
#                  price                          region  \
# 0   Price Upon Request                  Greece, Europe
# 1       160,000,000.00                  Thailand, Asia
# 2   Price Upon Request                   Spain, Europe
# 3        95,000,000.00          Florida, United States
# 4   Price Upon Request         Belize, Central America
# 5        65,000,000.00                  Maldives, Asia
# 6        62,000,000.00  The Exumas, Bahamas, Caribbean
# 7        60,000,000.00  The Exumas, Bahamas, Caribbean
# 8   Price Upon Request                  Poland, Europe
#
#                                                 tags
# 0  Large AcreageOcean IslandIncome PotentialMainl...
# 1  Islands with BeachesLarge AcreageOcean IslandI...
# 2  Large AcreageOcean IslandTurn KeyIncome Potential
# 3  Large AcreageOcean IslandTurn KeyIncome Potential
# 4  Large AcreageOcean IslandTurn KeyIncome Potential
# 5  Islands with BeachesAirstrip or Fly-inLarge Ac...
# 6  Islands with BeachesLarge AcreageOcean IslandI...
# 7  Islands with BeachesLarge AcreageOcean IslandT...
# 8  Large AcreageIncome ProducingLake IslandSeason...

# %%
# url = "https://www.privateislandsonline.com/search?availability=sale"
# page = 76
# island_data = []


# # max_num=0
# # for item in doc.select_one(".pagination"):
# #     if len(item.select('a'))>0:
# #         if item.select('a')[0].text !="»":
# #             if int(item.select('a')[0].text)>max_num:
# #                 max_num = int(item.select('a')[0].text)
# # print(max_num)

# while True:
#     print("---")
#     url = f"https://www.privateislandsonline.com/search?availability=sale&page={page}"
#     print("Requesting", url)
#     response = requests.get(url)
#     doc = BeautifulSoup(response.text, 'html.parser')

    
#     if len(doc.select('.grid')) ==0:
#         break
    
#     islands = doc.select('.grid')
#     rows = []
    
#     for island in islands:
#         print('-----')
#         row = {}

#         row['name'] = island.select_one('.name').text.strip()
#         try:
#             row['image'] = island.select_one('.islandImageWithoutBg')['src']
#         except:
#             print('No image link')

#         try:
#             row['acreage'] = island.select_one('.num').text.strip()
#         except:
#             print('No acreage')

#         try:
#             row['price'] = clean_table(island.select_one('.list-price').text.strip())
#         except:
#             print('No price')

#         try:
#             row['region'] = clean_table(island.select_one('.list-name').text.strip())
#         except:
#             print('No region data')

#         try:
#             row['tags'] = clean_table(island.select_one(".tags--listing").text.strip())
#         except: 
#             print('No tags')

#         print(row)
#         rows.append(row)
    
    
#     island_data.extend(doc)
#     page = page + 1
    
# island_df = pd.DataFrame(rows)
# island_df

# %%
import itertools
rows=[]
for i in itertools.count(start=1):
    url = f"https://www.privateislandsonline.com/search?availability=sale&page={i}"
    print(url)
    response = requests.get(url)
    doc = BeautifulSoup(response.text, 'html.parser')
    if len(doc.select('.grid'))==0:
        break
    else:
        islands = doc.select('.grid')
        for island in islands:
            print('-----')
            row = {}
            row['name'] = clean_table(island.select_one('.name').text.strip())
            try:
                row['image'] = island.select_one('.islandImageWithoutBg')['src']
            except:
                print('No image link')
            try:
                row['acreage'] = island.select_one('.num').text.strip()
            except:
                print('No acreage')
            try:
                row['price'] = clean_table(island.select_one('.list-price').text.strip())
            except:
                print('No price')
            try:
                row['region'] = clean_table(island.select_one('.list-name').text.strip())
            except:
                print('No region data')
            try:
                row['tags'] = clean_table(island.select_one(".tags--listing").text.strip())
            except: 
                print('No tags')
            print(row)
            rows.append(row)
# Out:
# https://www.privateislandsonline.com/search?availability=sale&page=1
# -----
# {'name': 'Island of Patroklos', 'image': 'https://www.privateislandsonline.com/uploads/resize/_885_5880dcf91ffc0.jpg-1074-822.jpg', 'acreage': '643', 'price': ' Price Upon Request', 'region': 'Greece, Europe', 'tags': 'Large AcreageOcean IslandIncome PotentialMainland Power'}
# -----
# {'name': 'Rangyai Island', 'image': 'https://www.privateislandsonline.com/uploads/resize/_597_image_fe02c338d8.jpg-1074-822.jpg', 'acreage': '110', 'price': '160,000,000.00', 'region': 'Thailand, Asia', 'tags': 'Islands with BeachesLarge AcreageOcean IslandIncome Potential'}
# -----
# No image link
# {'name': 'Blackbook Listing(2867)', 'acreage': '100 - 200', 'price': ' Price Upon Request', 'region': 'Spain, Europe', 'tags': 'Large AcreageOcean IslandTurn KeyIncome Potential'}
# -----
# {'name': 'Pumpkin Key', 'image': 'https://www.privateislandsonline.com/uploads/resize/_1682_60f97f2079fda.jpg-1074-822.jpg', 'acreage': '26', 'price': '95,000,000.00', 'region': 'Florida, United States', 'tags': 'Large AcreageOcean IslandTurn KeyIncome Potential'}
# -----
# {'name': 'Long Caye Private Island', 'image': 'https://www.privateislandsonline.com/uploads/resize/_2551_5c41c9b0cd95b.JPG-1074-822.JPG', 'acreage': '40', 'price': ' Price Upon Request', 'region': 'Belize, Central America', 'tags': 'Large AcreageOcean IslandTurn KeyIncome Potential'}
# -----
# {'name': 'Ifuru Resort with Airport and Funadhoo Island', 'image': 'https://www.privateislandsonline.com/uploads/resize/_2793_5ebb001ab79fb.jpg-1074-822.jpg', 'acreage': '169', 'price': '65,000,000.00', 'region': 'Maldives, Asia', 'tags': 'Islands with BeachesAirstrip or Fly-inLarge AcreageOcean IslandTurn KeyIncome Potential'}
# -----
# {'name': 'Spectabilis Island', 'image': 'https://www.privateislandsonline.com/uploads/resize/_1747_image_691ba69c7d.jpg-1074-822.jpg', 'acreage': '460', 'price': '62,000,000.00', 'region': 'The Exumas, Bahamas, Caribbean', 'tags': 'Islands with BeachesLarge AcreageOcean IslandIncome Potential'}
# -----
# {'name': 'Cave Cay', 'image': 'https://www.privateislandsonline.com/uploads/resize/_909_6026d75621ccf.jpg-1074-822.jpg', 'acreage': '220', 'price': '60,000,000.00', 'region': 'The Exumas, Bahamas, Caribbean', 'tags': 'Islands with BeachesLarge AcreageOcean IslandTurn KeyIncome Potential'}
# -----
# {'name': 'Schulzewerder Island', 'image': 'https://www.privateislandsonline.com/uploads/resize/_839_image_2555ca35dc.jpg-1074-822.jpg', 'acreage': '21', 'price': ' Price Upon Request', 'region': 'Poland, Europe', 'tags': 'Large AcreageIncome ProducingLake IslandSeasonalTurn KeyHistoricIncome Potential'}
# https://www.privateislandsonline.com/search?availability=sale&page=2
# -----
# {'name': 'Vouvalos Island', 'image': 'https://www.privateislandsonline.com/uploads/resize/_558_image_f6b64edf5a.jpg-1074-822.jpg', 'acreage': '32', 'price': ' Price Upon Request', 'region': 'Greece, Europe', 'tags': 'Large AcreageOcean Island'}
# -----
# No acreage
# {'name': 'Windermere', 'image': 'https://www.privateislandsonline.com/uploads/resize/_2548_5c3f78488f72b.jpg-1074-822.jpg', 'price': ' Price Upon Request', 'region': 'Eleuthera, Bahamas , Caribbean', 'tags': 'Islands with BeachesAirstrip or Fly-inLarge AcreageIncome ProducingOcean IslandTurn KeyHistoricIncome Potential'}
# -----
# {'name': 'Serenity Beaches Resort', 'image': 'https://www.privateislandsonline.com/uploads/resize/_2020_587fc33606fc4.jpg-1074-822.jpg', 'acreage': '8', 'price': ' Price Upon Request', 'region': 'Tonga, South Pacific', 'tags': 'Islands with BeachesIncome ProducingOcean IslandTurn Key'}
# -----
# {'name': 'Blue Dolphin Island', 'image': 'https://www.privateislandsonline.com/uploads/resize/_2010_58757e49a1777.jpg-1074-822.jpg', 'acreage': '104', 'price': ' Price Upon Request', 'region': 'Panama, Central America', 'tags': 'Large AcreageOcean IslandIncome Potential'}
# -----
# No acreage
# {'name': 'Amillarah Private Islands', 'image': 'https://www.privateislandsonline.com/uploads/resize/_1941_image_d64f51e345.jpg-1074-822.jpg', 'price': ' Price Upon Request', 'region': 'Maldives, Asia', 'tags': 'Islands with BeachesOcean IslandTurn KeyIncome Potential'}
# -----
# {'name': 'Ngerbelas Island', 'image': 'https://www.privateislandsonline.com/uploads/resize/_1930_image_b67b37defd.jpg-1074-822.jpg', 'acreage': '21', 'price': ' Sold', 'region': 'Palau, Asia', 'tags': 'Islands with BeachesLarge AcreageOcean Island'}
# -----
# {'name': 'Big Scrub Island', 'image': 'https://www.privateislandsonline.com/uploads/resize/_1817_5ab3b54a7eb3c.JPG-1074-822.JPG', 'acreage': '170', 'price': ' Price Upon Request', 'region': 'British Virgin Islands, Caribbean', 'tags': 'Islands with BeachesLarge AcreageOcean IslandIncome Potential'}
# -----
# {'name': 'Lovango Cay', 'image': 'https://www.privateislandsonline.com/uploads/resize/_1815_image_20b7123f37.jpg-1074-822.jpg', 'acreage': '5', 'price': ' Price Upon Request', 'region': 'US Virgin Islands, Caribbean', 'tags': 'Islands with BeachesOcean IslandTurn KeyIncome Potential'}
# -----
# {'name': 'Tojo Una Una Island', 'image': 'https://www.privateislandsonline.com/uploads/resize/_1779_image_7067840a6b.jpg-1074-822.jpg', 'acreage': '3089', 'price': ' Price Upon Request', 'region': 'Indonesia, Asia', 'tags': 'Islands with BeachesLarge AcreageOcean Island'}
# https://www.privateislandsonline.com/search?availability=sale&page=3
# -----
# No acreage
# {'name': 'Jost Van Dyke', 'image': 'https://www.privateislandsonline.com/uploads/resize/_1712_image_18edc564d6.jpg-1074-822.jpg', 'price': ' Price Upon Request', 'region': 'British Virgin Islands, Caribbean', 'tags': 'Islands with BeachesOcean IslandIncome Potential'}
# -----
# {'name': 'Steele Point', 'image': 'https://www.privateislandsonline.com/uploads/resize/_1708_5867be070eb08.jpg-1074-822.jpg', 'acreage': '8', 'price': ' Price Upon Request', 'region': 'British Virgin Islands, Caribbean', 'tags': 'Ocean IslandTurn KeyIncome Potential'}
# -----
# {'name': 'Long Island', 'image': 'https://www.privateislandsonline.com/uploads/resize/_1688_image_8c74456de9.jpg-1074-822.jpg', 'acreage': '4600', 'price': ' Price Upon Request', 'region': 'South Carolina, United States', 'tags': 'Large AcreageRiver Island'}
# -----
# {'name': 'Ginger Island', 'image': 'https://www.privateislandsonline.com/uploads/resize/_1644_image_5135650d93.jpg-1074-822.jpg', 'acreage': '258', 'price': ' Under Contract', 'region': 'British Virgin Islands, Caribbean', 'tags': 'Islands with BeachesLarge AcreageOcean IslandIncome Potential'}
# -----
# {'name': 'Praia do Algodao', 'image': 'https://www.privateislandsonline.com/uploads/resize/_1635_588910bc9595e.jpg-1074-822.jpg', 'acreage': '29', 'price': ' Price Upon Request', 'region': 'Brazil, South America', 'tags': 'Islands with BeachesIncome ProducingOcean IslandTurn KeyIncome Potential'}
# -----
# {'name': 'Treasure Cove', 'image': 'https://www.privateislandsonline.com/uploads/resize/_1632_image_0d2e3c8e6f.jpg-1074-822.jpg', 'acreage': '75', 'price': ' Price Upon Request', 'region': 'Belize, Central America', 'tags': 'Ocean Island'}
# -----
# {'name': 'Blunder Bay Estates', 'image': 'https://www.privateislandsonline.com/uploads/resize/_1566_image_50a10dc865.jpg-1074-822.jpg', 'acreage': '1', 'price': ' Price Upon Request', 'region': 'British Virgin Islands, Caribbean', 'tags': 'Islands with BeachesOcean IslandTurn KeyIncome Potential'}
# -----
# {'name': 'Waldron Island', 'image': 'https://www.privateislandsonline.com/uploads/resize/_1549_image_fe5584ad7b.jpg-1074-822.jpg', 'acreage': '50', 'price': ' Price Upon Request', 'region': 'Washington, United States', 'tags': 'Islands with BeachesAirstrip or Fly-inLarge AcreageLake IslandTurn KeyIncome Potential'}
# -----
# {'name': 'Mounu Island Resort', 'image': 'https://www.privateislandsonline.com/uploads/resize/_1454_587fc4291df23.jpg-1074-822.jpg', 'acreage': '7', 'price': ' Price Upon Request', 'region': 'Tonga, South Pacific', 'tags': 'Islands with BeachesIncome ProducingOcean Island'}
# https://www.privateislandsonline.com/search?availability=sale&page=4
# -----
# {'name': 'Pelican Island', 'image': 'https://www.privateislandsonline.com/uploads/resize/_1432_image_f98974dcac.jpg-1074-822.jpg', 'acreage': '32', 'price': ' Sold', 'region': 'Antigua, Caribbean', 'tags': 'Islands with BeachesOcean IslandIncome Potential'}
# -----
# No acreage
# {'name': 'The Ocean Flower', 'image': 'https://www.privateislandsonline.com/uploads/resize/_1409_image_4988120d79.jpg-1074-822.jpg', 'price': ' Off the Market', 'region': 'Maldives , Asia', 'tags': 'Ocean IslandTurn KeyIncome Potential'}
# -----
# {'name': 'Barefoot Cay Resort', 'image': 'https://www.privateislandsonline.com/uploads/resize/_1396_image_00e78f4261.jpg-1074-822.jpg', 'acreage': '8', 'price': ' Off the Market', 'region': 'Honduras, Central America', 'tags': 'Income ProducingOcean Island'}
# -----
# {'name': 'Verde Island Resort', 'image': 'https://www.privateislandsonline.com/uploads/resize/_1329_image_0a0417d5b8.jpg-1074-822.jpg', 'acreage': '274', 'price': ' Price Upon Request', 'region': 'Philippines, Asia', 'tags': 'Large AcreageIncome ProducingOcean Island'}
# -----
# {'name': 'Gopher Key Florida', 'image': 'https://www.privateislandsonline.com/uploads/resize/_1327_image_1b87f46b91.jpg-1074-822.jpg', 'acreage': '10', 'price': ' Price Upon Request', 'region': 'Florida, United States', 'tags': 'Ocean Island'}
# -----
# {'name': 'Isla Rancheria', 'image': 'https://www.privateislandsonline.com/uploads/resize/_430_image_e76aa795b3.jpg-1074-822.jpg', 'acreage': '310', 'price': ' Price Upon Request', 'region': 'Panama, Central America', 'tags': 'Islands with BeachesAirstrip or Fly-inLarge AcreageOcean Island'}
# -----
# No acreage
# {'name': 'The World Islands - Dubai', 'image': 'https://www.privateislandsonline.com/uploads/resize/_329_image_c7bcda7c32.jpg-1074-822.jpg', 'price': ' Price Upon Request', 'region': 'United Arab Emirates, Asia', 'tags': 'Islands with BeachesOcean IslandIncome PotentialMainland Power'}
# -----
# No image link
# {'name': 'Blackbook Listing(2521)', 'acreage': '300 - 400', 'price': ' Price Upon Request', 'region': 'SVG, Caribbean', 'tags': 'Islands with BeachesLarge AcreageOcean Island'}
# -----
# {'name': 'Royal Island', 'image': 'https://www.privateislandsonline.com/uploads/resize/_2885_60427f473db9a.jpg-1074-822.jpg', 'acreage': '430', 'price': '45,000,000.00', 'region': 'Eleuthera, Bahamas, Caribbean', 'tags': 'Islands with BeachesLarge AcreageOcean IslandTurn KeyIncome Potential'}
# https://www.privateislandsonline.com/search?availability=sale&page=5
# -----
# {'name': 'Dulichium Island', 'image': 'https://www.privateislandsonline.com/uploads/resize/_1354_image_c678fd30de.jpg-1074-822.jpg', 'acreage': '1335', 'price': '40,000,000.00', 'region': 'Greece, Europe', 'tags': 'Large AcreageOcean Island'}
# -----
# No image link
# {'name': 'Blackbook Listing(2106)', 'acreage': '300 - 500', 'price': ' Price Upon Request', 'region': 'Turks and Caicos, Caribbean', 'tags': 'Islands with BeachesLarge AcreageOc
 'image': 'https://www.privateislandsonline.com/uploads/resize/_2253_59442f1c1229f.jpg-1074-822.jpg', 'acreage': '13', 'price': '22,000,000.00', 'region': 'Florida, United States', 'tags': ''}
# -----
# {'name': 'Pakatoa Island', 'image': 'https://www.privateislandsonline.com/uploads/resize/_330_image_04b54e67cb.jpg-1074-822.jpg', 'acreage': '60', 'price': ' Price Upon Request', 'region': 'New Zealand, South Pacific', 'tags': 'Islands with BeachesLarge AcreageIncome ProducingOcean Island'}
# -----
# {'name': 'The Plantation', 'image': 'https://www.privateislandsonline.com/uploads/resize/_2456_5b76d19f222b4.jpg-1074-822.jpg', 'acreage': '495', 'price': '21,000,000.00', 'region': 'Belize, Central America', 'tags': 'Islands with BeachesLarge AcreageOcean Island'}
# -----
# {'name': 'Charles Island', 'image': 'https://www.privateislandsonline.com/uploads/resize/_2907_609ab96a9c2e8.jpg-1074-822.jpg', 'acreage': '55', 'price': ' Price Upon Request', 'region': 'Bahamas, Caribbean', 'tags': 'Islands with BeachesLarge AcreageOcean IslandMainland Power'}
# -----
# {'name': 'Half Moon Cay', 'image': 'https://www.privateislandsonline.com/uploads/resize/_2635_5d1b80f64c23e.JPG-1074-822.JPG', 'acreage': '10', 'price': ' Price Upon Request', 'region': 'Honduras, Central America', 'tags': 'Islands with BeachesOcean IslandTurn KeyIncome Potential'}
# -----
# No image link
# {'name': 'Blackbook Listing(2520)', 'acreage': '90 - 110', 'price': ' Price Upon Request', 'region': 'SVG, Caribbean', 'tags': 'Large AcreageOcean Island'}
# https://www.privateislandsonline.com/search?availability=sale&page=9
# -----
# {'name': 'Ile de Caille', 'image': 'https://www.privateislandsonline.com/uploads/resize/_905_image_3f4610a7c3.jpg-1074-822.jpg', 'acreage': '400', 'price': '20,000,000.00', 'region': 'Grenada, Caribbean', 'tags': 'Islands with BeachesLarge AcreageOcean IslandIncome Potential'}
# -----
# {'name': 'Broad Key', 'image': 'https://www.privateislandsonline.com/uploads/resize/_703_image_5dafa148e0.jpg-1074-822.jpg', 'acreage': '63', 'price': ' Off the Market', 'region': 'Florida, United States', 'tags': 'Large AcreageOcean IslandTurn KeyIncome Potential'}
# -----
# {'name': 'Little Ragged Island', 'image': 'https://www.privateislandsonline.com/uploads/resize/_126_6054f15e8cec3.jpg-1074-822.jpg', 'acreage': '730', 'price': ' Under Contract', 'region': 'Ragged Island Chain, Caribbean, Bahamas', 'tags': 'Islands with BeachesLarge AcreageOcean IslandIncome Potential'}
# -----
# {'name': 'Terzioglu Island', 'image': 'https://www.privateislandsonline.com/uploads/resize/_2759_5e87c17b9de93.jpg-1074-822.jpg', 'acreage': '66', 'price': ' Price Upon Request', 'region': 'Turkey, Europe', 'tags': 'Large AcreageLake Island'}
# -----
# {'name': 'Jwycesska Island', 'image': 'https://www.privateislandsonline.com/uploads/resize/_2700_5dbb1ec6dde92.jpg-1074-822.jpg', 'acreage': '351', 'price': '19,000,000.00', 'region': 'The Abacos, Bahamas, Caribbean', 'tags': 'Islands with BeachesLarge AcreageOcean Island'}
# -----
# {'name': 'Thatch Cay', 'image': 'https://www.privateislandsonline.com/uploads/resize/_2528_5be5b6fc3ec89.jpg-1074-822.jpg', 'acreage': '230', 'price': ' Price Upon Request', 'region': 'US Virgin Islands, Caribbean', 'tags': 'Islands with BeachesLarge AcreageOcean Island'}
# -----
# {'name': 'Pumpkin Island, Australia', 'image': 'https://www.privateislandsonline.com/uploads/resize/_2855_5fbd7098409e1.jpg-1074-822.jpg', 'acreage': '15', 'price': '18,500,000.00', 'region': 'Australia, South Pacific', 'tags': 'Islands with BeachesOcean IslandTurn KeyIncome Potential'}
# -----
# {'name': 'Little Bay Estate', 'image': 'https://www.privateislandsonline.com/uploads/resize/_2400_5c93b08491e74.jpg-1074-822.jpg', 'acreage': '7', 'price': ' Price Upon Request', 'region': 'British Virgin Islands, Caribbean', 'tags': 'Islands with BeachesOcean IslandTurn KeyIncome Potential'}
# -----
# {'name': 'Gumelemi Cay', 'image': 'https://www.privateislandsonline.com/uploads/resize/_1893_image_f6bd5af99a.jpg-1074-822.jpg', 'acreage': '8', 'price': ' Off the Market', 'region': 'The Abacos, Bahamas, Caribbean', 'tags': 'Islands with BeachesOcean IslandIncome Potential'}
# https://www.privateislandsonline.com/search?availability=sale&page=10
# -----
# {'name': '800-acre Golfito Bay Property', 'image': 'https://www.privateislandsonline.com/uploads/resize/_
', 'image': 'https://www.privateislandsonline.com/uploads/resize/_1697_5867ca5e297c0.jpg-1074-822.jpg', 'acreage': '4', 'price': ' Price Upon Request', 'region': 'British Virgin Islands, Caribbean', 'tags': 'Income ProducingOcean IslandTurn Key'}
# -----
# {'name': 'Water Caye', 'image': 'https://www.privateislandsonline.com/uploads/resize/_684_image_020821d040.jpg-1074-822.jpg', 'acreage': '567', 'price': '12,000,000.00', 'region': 'Belize, Central America', 'tags': 'Large AcreageOcean Island'}
# -----
# {'name': 'Green Island, Georgia', 'image': 'https://www.privateislandsonline.com/uploads/resize/_2838_5fb3f2b973e85.jpg-1074-822.jpg', 'acreage': '450', 'price': '11,500,000.00', 'region': 'Georgia, United States', 'tags': 'Large AcreageOcean IslandHistoricIncome Potential'}
# -----
# {'name': 'Pepin Island', 'image': 'https://www.privateislandsonline.com/uploads/resize/_2558_5c5ced70d3027.jpg-1074-822.jpg', 'acreage': '1280', 'price': ' Sold', 'region': 'New Zealand, South Pacific', 'tags': 'Islands with BeachesLarge AcreageOcean IslandTurn KeyIncome Potential'}
# -----
# {'name': 'The Duke Group Archipelago', 'image': 'https://www.privateislandsonline.com/uploads/resize/_1313_image_7b03699fe9.jpg-1074-822.jpg', 'acreage': '3300', 'price': '15,000,000.00', 'region': 'Australia, South Pacific', 'tags': 'Islands with BeachesAirstrip or Fly-inLarge AcreageOcean IslandTurn KeyIncome Potential'}
# -----
# {'name': 'Northern Aegean Island', 'image': 'https://www.privateislandsonline.com/uploads/resize/_1918_image_b49c3518dd.jpg-1074-822.jpg', 'acreage': '34', 'price': ' Price Upon Request', 'region': 'Greece, Europe', 'tags': 'Islands with BeachesLarge AcreageOcean Island'}
# https://www.privateislandsonline.com/search?availability=sale&page=14
# -----
# {'name': 'Spalathronisi Island', 'image': 'https://www.privateislandsonline.com/uploads/resize/_2457_5be5b0995e66f.jpg-1074-822.jpg', 'acreage': '26', 'price': '10,000,000.00', 'region': 'Greece, Europe', 'tags': 'Islands with BeachesLarge AcreageOcean Island'}
# -----
# {'name': 'Nakacha Huraa Lagoon', 'image': 'https://www.privateislandsonline.com/uploads/resize/_2597_5ccc93029ff08.JPG-1074-822.JPG', 'acreage': '29', 'price': '11,000,000.00', 'region': 'Maldives, Asia', 'tags': 'Islands with BeachesLarge AcreageOcean Island'}
# -----
# {'name': 'Isla Puerco', 'image': 'https://www.privateislandsonline.com/uploads/resize/_826_587657310b840.jpg-1074-822.jpg', 'acreage': '160', 'price': '11,000,000.00', 'region': 'Panama, Central America', 'tags': 'Islands with BeachesLarge AcreageOcean Island'}
# -----
# {'name': 'Pair of Fiji Islands', 'image': 'https://www.privateislandsonline.com/uploads/resize/_2683_5d97a1e6b59c7.jpg-1074-822.jpg', 'acreage': '25', 'price': ' Price Upon Request', 'region': 'Fiji, South Pacific', 'tags': 'Islands with BeachesLarge AcreageOcean Island'}
# -----
# {'name': 'Punta Loros', 'image': 'https://www.privateislandsonline.com/uploads/resize/_2924_60e73a4e3f9f0.jpg-1074-822.jpg', 'acreage': '460', 'price': '10,900,000.00', 'region': 'Costa Rica, Central America', 'tags': 'Islands with BeachesLarge AcreageOcean Island'}
# -----
# {'name': 'Lambay Cay', 'image': 'https://www.privateislandsonline.com/uploads/resize/_2317_5be5ddd4e1545.jpg-1074-822.jpg', 'acreage': '7', 'price': ' Price Upon Request', 'region': 'Honduras, Central America', 'tags': 'Islands with BeachesOcean Island'}
# -----
# {'name': 'Toad Hall Estate', 'image': 'https://www.privateislandsonline.com/uploads/resize/_1819_image_7c8cf5f011.jpg-1074-822.jpg', 'acreage': '6', 'price': '10,000,000.00', 'region': 'British Virgin Islands, Caribbean', 'tags': 'Income ProducingTurn Key'}
# -----
# No image link
# {'name': 'Blackbook Listing(2096)', 'acreage': '20 - 40', 'price': ' Price Upon Request', 'region': 'Seychelles, Africa', 'tags': 'Islands with BeachesLarge AcreageIncome ProducingOcean IslandTurn Key'}
# -----
# {'name': 'Young Island Resort', 'image': 'https://www.privateislandsonline.com/uploads/resize/_1444_image_12db537f95.jpg-1074-822.jpg', 'acreage': '13', 'price': '10,000,000.00', 'region': 'SVG, Caribbean', 'tags': 'Islands with BeachesIncome ProducingOcean IslandTurn Key'}
# https://www.privateislandsonline.com/search?availability=sale&page=15
# -----
# {'name': 'Denarau Peninsula', 'image': 'https://www.privateislandsonline.com/uploads/resize/_
 'tags': 'Islands with BeachesLarge AcreageOcean Island'}
# -----
# {'name': 'Batchawana Island', 'image': 'https://www.privateislandsonline.com/uploads/resize/_2413_60b8f251100c5.jpg-1074-822.jpg', 'acreage': '5200', 'price': '8,000,000.00', 'region': 'Ontario, Canada', 'tags': 'Large AcreageLake Island'}
# -----
# {'name': 'Sandy Cay', 'image': 'https://www.privateislandsonline.com/uploads/resize/_1207_image_3526b283d4.jpg-1074-822.jpg', 'acreage': '8', 'price': ' Sold', 'region': 'The Abacos, Bahamas, Caribbean', 'tags': 'Islands with BeachesOcean IslandTurn KeyIncome Potential'}
# -----
# {'name': 'Nukudrau Island', 'image': 'https://www.privateislandsonline.com/uploads/resize/_1782_image_f5be1c7661.jpg-1074-822.jpg', 'acreage': '46', 'price': ' Price Upon Request', 'region': 'Fiji, South Pacific', 'tags': 'Islands with BeachesLarge AcreageOcean IslandIncome Potential'}
# https://www.privateislandsonline.com/search?availability=sale&page=17
# -----
# {'name': 'Sipson Island', 'image': 'https://www.privateislandsonline.com/uploads/resize/_2395_5aeb2cfb2153a.jpg-1074-822.jpg', 'acreage': '25', 'price': ' Sold', 'region': 'Massachusetts, United States', 'tags': 'Islands with BeachesLarge AcreageOcean IslandTurn KeyHistoricIncome PotentialMainland Lot'}
# -----
# {'name': 'Hope Island', 'image': 'https://www.privateislandsonline.com/uploads/resize/_2374_5aa819870d9c5.jpg-1074-822.jpg', 'acreage': '86', 'price': ' Off the Market', 'region': 'Maine, United States', 'tags': 'Large AcreageOcean IslandTurn KeyIncome Potential'}
# -----
# {'name': 'Devils Cay', 'image': 'https://www.privateislandsonline.com/uploads/resize/_902_image_c458691ab3.jpg-1074-822.jpg', 'acreage': '117', 'price': '7,950,000.00', 'region': 'The Berry Islands, Bahamas, Caribbean', 'tags': 'Islands with BeachesLarge AcreageOcean IslandIncome Potential'}
# -----
# {'name': 'Katitche Point Greathouse', 'image': 'https://www.privateislandsonline.com/uploads/resize/_2002_5867c22ac0204.jpg-1074-822.jpg', 'acreage': '1', 'price': '7,950,000.00', 'region': 'British Virgin Islands, Caribbean', 'tags': 'Income ProducingTurn Key'}
# -----
# {'name': 'Powell Cay', 'image': 'https://www.privateislandsonline.com/uploads/resize/_1614_image_d1e3cfaa39.jpg-1074-822.jpg', 'acreage': '294', 'price': '7,895,000.00', 'region': 'The Abacos, Bahamas, Caribbean', 'tags': 'Islands with BeachesLarge AcreageOcean IslandIncome Potential'}
# -----
# {'name': 'Woodmere Island', 'image': 'https://www.privateislandsonline.com/uploads/resize/_1459_image_8148017b4f.jpg-1074-822.jpg', 'acreage': '5', 'price': '7,895,000.00', 'region': 'Muskoka, Ontario, Canada', 'tags': 'Lake IslandSeasonalTurn KeyIncome PotentialMainland Power'}
# -----
# {'name': 'Kato Antikeri Island', 'image': 'https://www.privateislandsonline.com/uploads/resize/_1342_image_c271b76d19.jpg-1074-822.jpg', 'acreage': '272', 'price': ' Price Upon Request', 'region': 'Greece, Europe', 'tags': 'Large AcreageOcean Island'}
# -----
# {'name': 'The Bay', 'image': 'https://www.privateislandsonline.com/uploads/resize/_2925_60e739c33296e.jpg-1074-822.jpg', 'acreage': '148', 'price': '7,700,000.00', 'region': 'Costa Rica, Central America', 'tags': 'Islands with BeachesLarge AcreageOcean Island'}
# -----
# No image link
# {'name': 'Blackbook Listing(2816)', 'acreage': '0 - 0', 'price': ' Price Upon Request', 'region': 'Bahamas, Caribbean', 'tags': 'Islands with BeachesIncome ProducingOcean IslandTurn KeyIncome Potential'}
# https://www.privateislandsonline.com/search?availability=sale&page=18
# -----
# {'name': 'Petit Trou Peninsula', 'image': 'https://www.privateislandsonline.com/uploads/resize/_1174_5fb40030a79c3.jpg-1074-822.jpg', 'acreage': '50', 'price': '7,500,000.00', 'region': 'Grenada, Caribbean', 'tags': 'Islands with BeachesLarge AcreageOcean Island'}
# -----
# {'name': 'Leaf Cay', 'image': 'https://www.privateislandsonline.com/uploads/resize/_921_image_97ac5163fc.jpg-1074-822.jpg', 'acreage': '30', 'price': '7,500,000.00', 'region': 'The Exumas, Bahamas, Caribbean', 'tags': 'Islands with BeachesOcean IslandIncome Potential'}
# -----
# {'name': 'Parida Island', 'image': 'https://www.privateislandsonline.com/uploads/resize/_2297_59aeea773d8d5.PNG-1074-822.PNG', 'acreage': '217', 'price': '7,500,000.00', 'region': 'Panama, Central America', 'tags': 'Islands with BeachesAirstrip or Fly-inLarge AcreageOcean IslandTurn KeyIncome Potential'}
# -----
# {'name': 'Roberts Cay', 'image': 'https://www.privateislandsonline.com/uploads/resize/_917_image_ce1186328a.jpg-1074-822.jpg', 'acreage': '20', 'price': '7,205,000.00', 'region': 'The Exumas, Bahamas, Caribbean', 'tags': 'Islands with BeachesOcean IslandIncome Potential'}
# -----
# {'name': 'Sand Dollar Cay', 'image': 'https://www.privateislandsonline.com/uploads/resize/_908_image_e069a07d0c.jpg-1074-822.jpg', 'acreage': '24', 'price': '7,200,000.00', 'region': 'The Berry Islands, Bahamas, Caribbean', 'tags': 'Islands with BeachesOcean IslandIncome Potential'}
# -----
# {'name': "Sawyer's Cay", 'image': 'https://www.privateislandsonline.com/uploads/resize/_930_image_759eaf43be.jpg-1074-822.jpg', 'acreage': '6', 'price': '7,050,000.00', 'region': 'Eleuthera, Bahamas, Caribbean', 'tags': 'Islands with BeachesOcean IslandIncome Potential'}
# -----
# {'name': 'Motu Rauoro', 'image': 'https://www.privateislandsonline.com/uploads/resize/_2136_587e463b59d2b.jpg-1074-822.jpg', 'acreage': '18', 'price': ' Off the Market', 'region': 'French Polynesia, South Pacific', 'tags': 'Islands with BeachesOcean Island'}
# -----
# {'name': 'Elysian Retreat', 'image': 'https://www.privateislandsonline.com/uploads/resize/_2861_5fcf9b53228e0.jpg-1074-822.jpg', 'acreage': '8', 'price': ' Price Upon Request', 'region': 'Australia , South Pacific', 'tags': 'Islands with BeachesIncome ProducingOcean IslandTurn KeyIncome Potential'}
# -----
# {'name': '42-Acre Private Island West of Placencia Village', 'image': 'https://www.privateislandsonline.com/uploads/resize/_2680_5ef4e5f7d9e6a.jpg-1074-822.jpg', 'acreage': '42', 'price': ' Price Upon Request', 'region': 'Belize, Central America', 'tags': 'Large AcreageOcean Island'}
# https://www.privateislandsonline.com/search?availability=sale&page=19
# -----
# {'name': 'Kandoo Island', 'image': 'https://www.privateislandsonline.com/uploads/resize/_1410_image_71316e4ffe.jpg-1074-822.jpg', 'acreage': '42', 'price': ' Price Upon Request', 'region': 'Maldives, Asia', 'tags': 'Islands with BeachesLarge AcreageIncome ProducingOcean IslandTurn KeyIncome Potential'}
# -----
# {'name': "Frenchman's Caye", 'image': 'https://www.privateislandsonline.com/uploads/resize/_1203_59c932b598ee8.jpg-1074-822.jpg', 'acreage': '200', 'price': ' Price Upon Request', 'region': 'Belize, Central America', 'tags': 'Large AcreageOcean Island'}
# -----
# {'name': 'Coral Island, Maldives', 'image': 'https://www.privateislandsonline.com/uploads/resize/_2794_5ebc5f2ca76bf.jpg-1074-822.jpg', 'acreage': '45', 'price': ' Price Upon Request', 'region': 'Maldives, Asia', 'tags': 'Islands with BeachesLarge AcreageOcean Island'}
# -----
# {'name': 'Crystal Island', 'image': 'https://www.privateislandsonline.com/uploads/resize/_2795_5ebc5fad932b8.jpg-1074-822.jpg', 'acreage': '103', 'price': ' Price Upon Request', 'region': 'Maldives , Asia', 'tags': 'Islands with BeachesLarge AcreageOcean Island'}
# -----
# ...
# -----
# {'name': 'Tahifehifa Island', 'image': 'https://www.privateislandsonline.com/uploads/resize/_749_image_cd0b177898.jpg-1074-822.jpg', 'acreage': '1', 'price': ' Off the Market', 'region': 'Tonga, South Pacific', 'tags': 'Islands with BeachesOcean Island'}
# -----
# {'name': 'Pickerel Pine Island', 'image': 'https://www.privateislandsonline.com/uploads/resize/_1371_image_84451398c3.jpg-1074-822.jpg', 'acreage': '3', 'price': ' Off the Market', 'region': 'Ontario, Canada', 'tags': ''}
# -----
# {'name': 'Majestic Island', 'image': 'https://www.privateislandsonline.com/uploads/resize/_2373_5fb3fcd144d1e.jpg-1074-822.jpg', 'acreage': '1', 'price': ' Sold', 'region': 'Wisconsin, United States', 'tags': 'Lake IslandTurn KeyIncome Potential'}
# https://www.privateislandsonline.com/search?availability=sale&page=72
# -----
# {'name': 'Standerson Island', 'image': 'https://www.privateislandsonline.com/uploads/resize/_2036_image_9efb48dfb3.jpg-1074-822.jpg', 'acreage': '27', 'price': ' Sold', 'region': 'Michigan, United States', 'tags': 'Large AcreageLake Island'}
# -----
# {'name': 'Mowat Island L-727', 'image': 'https://www.privateislandsonline.com/uploads/resize/_1742_image_39f45129f5.jpg-1074-822.jpg', 'acreage': '14', 'price': ' Sold', 'region': 'Ontario, Canada', 'tags': 'Lake IslandSeasonal'}
# -----
# {'name': 'Deo Gratia', 'image': 'https://www.privateislandsonline.com/uploads/resize/_1821_image_c69a309113.jpg-1074-822.jpg', 'acreage': '3', 'price': '300,000.00', 'region': 'French River Area, Ontario, Canada', 'tags': 'River IslandSeasonalTurn KeyIncome Potential'}
# -----
# {'name': '1-Acre Private Island near Riversdale, Placencia', 'image': 'https://www.privateislandsonline.com/uploads/resize/_2663_5de7f9447efe7.jpg-1074-822.jpg', 'acreage': '1', 'price': '300,000.00', 'region': 'Belize, Central America', 'tags': 'Ocean Island'}
# -----
# {'name': 'Bensley Island', 'image': 'https://www.privateislandsonline.com/uploads/resize/_2228_59b941d315082.JPG-1074-822.JPG', 'acreage': '12', 'price': '300,000.00', 'region': 'Georgian Bay, Ontario, Canada', 'tags': 'Lake Island'}
# -----
# {'name': 'Punta Laurel Island', 'image': 'https://www.privateislandsonline.com/uploads/resize/_2751_5e595f2920931.jpg-1074-822.jpg', 'acreage': '10', 'price': '300,000.00', 'region': 'Panama, Central America', 'tags': 'Ocean Island'}
# -----
# {'name': 'Deadman Caye 1.4 acres', 'image': 'https://www.privateislandsonline.com/uploads/resize/_2034_587a3533c9508.jpg-1074-822.jpg', 'acreage': '1', 'price': ' Sold', 'region': 'Belize, Central America', 'tags': 'Islands with BeachesOcean Island'}
# -----
# {'name': 'Gullah Island', 'image': 'https://www.privateislandsonline.com/uploads/resize/_2291_598c7e73c68cd.jpg-1074-822.jpg', 'acreage': '3', 'price': '299,000.00', 'region': 'South Carolina, United States', 'tags': 'Ocean Island'}
# -----
# {'name': 'Narrows Island', 'image': 'https://www.privateislandsonline.com/uploads/resize/_411_image_ae9581fda7.jpg-1074-822.jpg', 'acreage': '6', 'price': ' Sold', 'region': 'Maine, United States', 'tags': 'Lake Island'}
# https://www.privateislandsonline.com/search?availability=sale&page=73
# -----
# {'name': 'Stono Island', 'image': 'https://www.privateislandsonline.com/uploads/resize/_2321_5a0ca42856f83.JPG-1074-822.JPG', 'acreage': '1', 'price': ' Sold', 'region': 'South Carolina, United States', 'tags': 'River Island'}
# -----
# {'name': 'Lark Caye', 'image': 'https://www.privateislandsonline.com/uploads/resize/_2265_594d3ddca96ac.jpg-1074-822.jpg', 'acreage': '3', 'price': '295,000.00', 'region': 'Belize, Central America', 'tags': 'Islands with BeachesOcean Island'}
# -----
# {'name': 'Mannions Island', 'image': 'https://www.privateislandsonline.com/uploads/resize/_740_597a23eb5ebe4.jpg-1074-822.jpg', 'acreage': '4', 'price': '230,000.00', 'region': 'Ireland, Europe', 'tags': 'Ocean Island'}
# -----
# {'name': 'Wedding Cake Island', 'image': 'https://www.privateislandsonline.com/uploads/resize/_1601_586bd1b26d0a3.jpg-1074-822.jpg', 'acreage': '1', 'price': ' Sold', 'region': 'Ontario, Canada', 'tags': 'Lake IslandSeasonalTurn KeyMainland Lot'}
# -----
# {'name': 'Saddle Caye 2.19', 'image': 'https://www.privateislandsonline.com/uploads/resize/_2051_image_fb9208da5c.jpg-1074-822.jpg', 'acreage': '2', 'price': '275,000.00', 'region': 'Belize, Central America', 'tags': 'Ocean Island'}
# -----
# {'name': 'Little Gaulding Cay', 'image': 'https://www.privateislandsonline.com/uploads/resize/_916_image_112a173b5c.jpg-1074-822.jpg', 'acreage': '2', 'price': ' Sold', 'region': 'The Berry Islands, Bahamas, Caribbean', 'tags': 'Ocean IslandIncome Potential'}
# -----
# {'name': 'Spider Caye', 'image': 'https://www.privateislandsonline.com/uploads/resize/_2550_5c41ca42ce148.PNG-1074-822.PNG', 'acreage': '1', 'price': '275,000.00', 'region': 'Belize , Central America', 'tags': 'Islands with BeachesOcean Island'}
# -----
# {'name': 'Richards Island', 'image': 'https://www.privateislandsonline.com/uploads/resize/_1971_58693a5ed0375.jpg-1074-822.jpg', 'acreage': '30', 'price': '274,500.00', 'region': 'Nova Scotia, Canada', 'tags': 'Ocean IslandSeasonalTurn KeyIncome Potential'}
# -----
# {'name': 'Frenchman Island', 'image': 'https://www.privateislandsonline.com/uploads/resize/_2892_605a25a655f5e.jpg-1074-822.jpg', 'acreage': '106', 'price': ' Sold', 'region': 'Ontario, Canada', 'tags': 'Large AcreageLake IslandHistoric'}
# https://www.privateislandsonline.com/search?availability=sale&page=74
# -----
# {'name': 'Win Island', 'image': 'https://www.privateislandsonline.com/uploads/resize/_1575_image_c3f46729a0.jpg-1074-822.jpg', 'acreage': '2', 'price': ' Sold', 'region': 'French River Area, Ontario, Canada', 'tags': 'Lake IslandTurn KeyIncome Potential'}
# -----
# No acreage
# {'name': 'Long Caye Island Property', 'image': 'https://www.privateislandsonline.com/uploads/resize/_421_5d4dea0c40601.jpg-1074-822.jpg', 'price': '254,000.00', 'region': 'Belize, Central America', 'tags': 'Islands with BeachesIncome ProducingOcean IslandIncome Potential'}
# -----
# {'name': 'Pink Pearl Island', 'image': 'https://www.privateislandsonline.com/uploads/resize/_852_587a9cc4725c0.jpg-1074-822.jpg', 'acreage': '1', 'price': ' Sold', 'region': 'Nicaragua, Central America', 'tags': 'Islands with BeachesOcean Island'}
# -----
# {'name': 'Danhattan Island', 'image': 'https://www.privateislandsonline.com/uploads/resize/_2805_5eed04354fd67.jpg-1074-822.jpg', 'acreage': '1', 'price': ' Sold', 'region': 'Connecticut, United States', 'tags': 'Lake IslandRiver IslandTurn KeyIncome Potential'}
# -----
# {'name': 'Black Island', 'image': 'https://www.privateislandsonline.com/uploads/resize/_1837_image_6da3a6c849.jpg-1074-822.jpg', 'acreage': '20', 'price': '325,000.00', 'region': 'Nova Scotia, Canada', 'tags': 'Lake IslandSeasonal'}
# -----
# {'name': 'Middle Island', 'image': 'https://www.privateislandsonline.com/uploads/resize/_325_image_26f553d641.jpg-1074-822.jpg', 'acreage': '38', 'price': '300,000.00', 'region': 'Nova Scotia, Canada', 'tags': 'Ocean IslandSeasonal'}
# -----
# {'name': 'Natural Inlet Island', 'image': 'https://www.privateislandsonline.com/uploads/resize/_1664_image_44b1472886.jpg-1074-822.jpg', 'acreage': '2', 'price': ' Sold', 'region': 'Ontario, Canada', 'tags': ''}
# -----
# {'name': 'Morrow Island', 'image': 'https://www.privateislandsonline.com/uploads/resize/_2743_5e39cb065c827.JPG-1074-822.JPG', 'acreage': '4', 'price': '200,000.00', 'region': 'Maine, United States', 'tags': 'Lake Island'}
# -----
# {'name': 'Deadman Caye .699acres', 'image': 'https://www.privateislandsonline.com/uploads/resize/_2032_587a3af47a450.jpg-1074-822.jpg', 'acreage': '1', 'price': ' Sold', 'region': 'Belize, Central America', 'tags': 'Islands with BeachesOcean Island'}
# https://www.privateislandsonline.com/search?availability=sale&page=75
# -----
# {'name': 'Island JD 181', 'image': 'https://www.privateislandsonline.com/uploads/resize/_2745_5e3da314f224d.jpg-1074-822.jpg', 'acreage': '2', 'price': ' Sold', 'region': 'Ontario, Canada', 'tags': 'Lake IslandTurn KeyIncome Potential'}
# -----
# {'name': 'Harbour Island', 'image': 'https://www.privateislandsonline.com/uploads/resize/_2272_5b33b0f5c2988.jpg-1074-822.jpg', 'acreage': '2', 'price': ' Sold', 'region': 'Nova Scotia, Canada', 'tags': 'Lake IslandTurn KeyIncome Potential'}
# -----
# {'name': 'Bear Island', 'image': 'https://www.privateislandsonline.com/uploads/resize/_1883_image_f7b813a80c.jpg-1074-822.jpg', 'acreage': '7', 'price': ' Sold', 'region': 'Nova Scotia, Canada', 'tags': 'Ocean IslandMainland Lot'}
# -----
# {'name': 'Sarrat Island', 'image': 'https://www.privateislandsonline.com/uploads/resize/_2030_image_8d8512763e.jpg-1074-822.jpg', 'acreage': '2', 'price': ' Sold', 'region': 'Northern Ontario, Ontario, Canada', 'tags': ''}
# -----
# {'name': 'Pearl Island', 'image': 'https://www.privateislandsonline.com/uploads/resize/_1370_5967a1c8bc43b.JPG-1074-822.JPG', 'acreage': '1', 'price': ' Sold', 'region': 'Georgian Bay, Ontario, Canada', 'tags': 'Lake IslandSeasonalTurn KeyIncome Potential'}
# -----
# {'name': 'Stewards Island', 'image': 'https://www.privateislandsonline.com/uploads/resize/_1320_image_b3dfbe0a63.jpg-1074-822.jpg', 'acreage': '54', 'price': ' Sold', 'region': 'Pennsylvania , United States', 'tags': 'Large AcreageRiver Island'}
# -----
# {'name': 'Spuhn Island Lots', 'image': 'https://www.privateislandsonline.com/uploads/resize/_834_image_8b33debf76.jpg-1074-822.jpg', 'acreage': '2', 'price': '169,900.00', 'region': 'Alaska, United States', 'tags': 'Islands with BeachesOcean IslandMainland Power'}
# -----
# {'name': 'Calf Island', 'image': 'https://www.privateislandsonline.com/uploads/resize/_1582_image_891695cabc.jpg-1074-822.jpg', 'acreage': '26', 'price': '220,000.00', 'region': 'Nova Scotia, Canada', 'tags': 'Ocean IslandSeasonal'}
# -----
# {'name': 'Chetek Lake Island', 'image': 'https://www.privateislandsonline.com/uploads/resize/_2856_5fbd66f01252e.jpg-1074-822.jpg', 'acreage': '6', 'price': '165,000.00', 'region': 'Wisconsin, United States', 'tags': 'Lake Island'}
# https://www.privateislandsonline.com/search?availability=sale&page=76
# -----
# {'name': 'Orchid Islands', 'image': 'https://www.privateislandsonline.com/uploads/resize/_2685_5d9fa2b6ec2af.jpg-1074-822.jpg', 'acreage': '1', 'price': '165,000.00', 'region': 'Belize, Central America', 'tags': 'Ocean Island'}
# -----
# {'name': 'Lake Nipissing Island C-905', 'image': 'https://www.privateislandsonline.com/uploads/resize/_1741_586b902ddc6a9.jpg-1074-822.jpg', 'acreage': '1', 'price': ' Sold', 'region': 'French River Area, Ontario , Canada', 'tags': 'Lake IslandSeasonalTurn KeyIncome Potential'}
# -----
# {'name': 'Rock Island', 'image': 'https://www.privateislandsonline.com/uploads/resize/_2352_5a3abf1d12ebd.jpg-1074-822.jpg', 'acreage': '1', 'price': ' Sold', 'region': 'Connecticut, United States', 'tags': 'Lake IslandTurn Key'}
# -----
# {'name': 'Cockroach Bay', 'image': 'https://www.privateislandsonline.com/uploads/resize/_1854_5877bab177bce.jpg-1074-822.jpg', 'acreage': '10', 'price': '150,000.00', 'region': 'Belize, Central America', 'tags': 'Islands with BeachesOcean Island'}
# -----
# {'name': '9.3-acre Private Island near Bocas', 'image': 'https://www.privateislandsonline.com/uploads/resize/_2910_60ae5a6b46665.jpg-1074-822.jpg', 'acreage': '9', 'price': '150,000.00', 'region': 'Panama, Central America', 'tags': 'Islands with BeachesOcean Island'}
# -----
# {'name': 'Deadman Caye .941 acres', 'image': 'https://www.privateislandsonline.com/uploads/resize/_2033_587a34b1742b9.jpg-1074-822.jpg', 'acreage': '1', 'price': ' Sold', 'region': 'Belize, Central America', 'tags': 'Islands with BeachesOcean Island'}
# -----
# No acreage
# {'name': 'Waterfront Lots in the Placencia Yacht Club', 'image': 'https://www.privateislandsonline.com/uploads/resize/_2698_5db33a8114f5c.jpg-1074-822.jpg', 'price': '145,000.00', 'region': 'Belize, Central America', 'tags': 'Ocean Island'}
# -----
# {'name': 'No Mans Island', 'image': 'https://www.privateislandsonline.com/uploads/resize/_2658_5d654985097ef.jpg-1074-822.jpg', 'acreage': '19', 'price': '125,000.00', 'region': 'New Jersey, United States', 'tags': 'Large AcreageLake Island'}
# -----
# {'name': 'Leader Island', 'image': 'https://www.privateislandsonline.com/uploads/resize/_388_595a6a3a9f436.jpg-1074-822.jpg', 'acreage': '11', 'price': ' Sold', 'region': 'Nova Scotia, Canada', 'tags': 'Ocean IslandSeasonalMainland Lot'}
# https://www.privateislandsonline.com/search?availability=sale&page=77
# -----
# No acreage
# {'name': 'Tierra Oscura Island Pair', 'image': 'https://www.privateislandsonline.com/uploads/resize/_2818_5f2adc59626e9.jpg-1074-822.jpg', 'price': '120,000.00', 'region': 'Panama, Central America', 'tags': 'Ocean Island'}
# -----
# {'name': 'Hangover Island', 'image': 'https://www.privateislandsonline.com/uploads/resize/_63_image_0db7e104de.jpg-1074-822.jpg', 'acreage': '40', 'price': ' Sold', 'region': 'Florida, United States', 'tags': 'Islands with BeachesLarge AcreageRiver Island'}
# -----
# {'name': 'Gillis Island', 'image': 'https://www.privateislandsonline.com/uploads/resize/_2385_5ace6fbaab355.jpg-1074-822.jpg', 'acreage': '11', 'price': '110,000.00', 'region': 'Prince Edward Island, Canada', 'tags': 'River IslandHistoric'}
# -----
# {'name': "Ken's Island", 'image': 'https://www.privateislandsonline.com/uploads/resize/_2900_607082a20fc42.jpg-1074-822.jpg', 'acreage': '1', 'price': '144,900.00', 'region': 'Ontario, Canada', 'tags': 'River Island'}
# -----
# {'name': 'La Cornelia Island', 'image': 'https://www.privateislandsonline.com/uploads/resize/_1940_image_0a5aa72a8e.jpg-1074-822.jpg', 'acreage': '1', 'price': '90,000.00', 'region': 'Nicaragua, Central America', 'tags': 'Lake IslandMainland Power'}
# -----
# {'name': 'Blowfish Island', 'image': 'https://www.privateislandsonline.com/uploads/resize/_2919_60d2259b7725c.JPG-1074-822.JPG', 'acreage': '6', 'price': '79,000.00', 'region': 'Panama, Central America', 'tags': 'Ocean Island'}
# -----
# {'name': 'Half Island', 'image': 'https://www.privateislandsonline.com/uploads/resize/_2274_595a830ca1292.PNG-1074-822.PNG', 'acreage': '6', 'price': '79,000.00', 'region': 'Nova Scotia, Canada', 'tags': 'Islands with BeachesLake IslandMainland Lot'}
# -----
# {'name': 'Sweet Island', 'image': 'https://www.privateislandsonline.com/uploads/resize/_838_image_41019fd393.jpg-1074-822.jpg', 'acreage': '3', 'price': ' Sold', 'region': 'British Columbia, Canada', 'tags': 'Lake IslandIncome Potential'}
# -----
# No acreage
# {'name': 'Bone Fish Caye', 'image': 'https://www.privateislandsonline.com/uploads/resize/_2687_5d9fa2452cee6.jpg-1074-822.jpg', 'price': '69,500.00', 'region': 'Belize, Central America', 'tags': 'Ocean Island'}
# https://www.privateislandsonline.com/search?availability=sale&page=78
# -----
# {'name': 'Big Tancook Island', 'image': 'https://www.privateislandsonline.com/uploads/resize/_1631_image_b908150be2.jpg-1074-822.jpg', 'acreage': '12', 'price': '90,000.00', 'region': 'Nova Scotia, Canada', 'tags': 'Ocean IslandSeasonal'}
# -----
# {'name': 'Gautier Island', 'image': 'https://www.privateislandsonline.com/uploads/resize/_2454_5b9ff627ecbfb.jpg-1074-822.jpg', 'acreage': '3', 'price': ' Sold', 'region': 'Mississippi, United States', 'tags': 'Ocean Island'}
# -----
# {'name': 'Blackbook Listing(2879)', 'image': 'https://www.privateislandsonline.com/uploads/resize/_2879_609937f382bbe.jpg-1074-822.jpg', 'acreage': '60 - 70', 'price': ' Investment Opportunity', 'region': 'Florida, United States', 'tags': 'Islands with BeachesLarge AcreageOcean IslandMainland Lot'}
# -----
# {'name': 'Spanish Lookout Caye', 'image': 'https://www.privateislandsonline.com/uploads/resize/_1910_5877b7047c4cb.jpg-1074-822.jpg', 'acreage': '186', 'price': ' Sold', 'region': 'Belize, Central America', 'tags': 'Islands with BeachesLarge AcreageIncome ProducingOcean Island'}
# -----
# No image link
# {'name': 'Blackbook Listing(2926)', 'acreage': '50 - 100', 'price': ' Price Upon Request', 'region': 'Maine, United States', 'tags': 'Islands with BeachesLarge AcreageTurn Key'}
# https://www.privateislandsonline.com/search?availability=sale&page=79

# %%
island_df = pd.DataFrame(rows)

# %%
island_df['tags'] = island_df.tags.str.replace(r'([a-z])([A-Z])', r'\1,\2', regex=True)

# %%
from datetime import datetime

island_df['scrape_date'] = pd.datetime.today().date()
# Out:
# <ipython-input-17-209150d3a15f>:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   island_df['scrape_date'] = pd.datetime.today().date()

# %%
island_df.to_csv('island_scrape.csv')

# %%
island_df['price'] = island_df.price.str.replace(',', '').str.replace(r'[a-zA-Z]', '')
island_df['price'] = pd.to_numeric(island_df['price'], errors = 'coerce')
# Out:
# <ipython-input-19-1b76f5cd2a3b>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   island_df['price'] = island_df.price.str.replace(',', '').str.replace(r'[a-zA-Z]', '')

# %%
island_df.sort_values('price')
# Out:
#                         name  \
# 692           Bone Fish Caye
# 690              Half Island
# 689          Blowfish Island
# 693       Big Tancook Island
# 688       La Cornelia Island
# ..                       ...
# 691             Sweet Island
# 694           Gautier Island
# 695  Blackbook Listing(2879)
# 696     Spanish Lookout Caye
# 697  Blackbook Listing(2926)
#
#                                                  image   acreage    price  \
# 692  https://www.privateislandsonline.com/uploads/r...       NaN  69500.0
# 690  https://www.privateislandsonline.com/uploads/r...         6  79000.0
# 689  https://www.privateislandsonline.com/uploads/r...         6  79000.0
# 693  https://www.privateislandsonline.com/uploads/r...        12  90000.0
# 688  https://www.privateislandsonline.com/uploads/r...         1  90000.0
# ..                                                 ...       ...      ...
# 691  https://www.privateislandsonline.com/uploads/r...         3      NaN
# 694  https://www.privateislandsonline.com/uploads/r...         3      NaN
# 695  https://www.privateislandsonline.com/uploads/r...   60 - 70      NaN
# 696  https://www.privateislandsonline.com/uploads/r...       186      NaN
# 697                                                NaN  50 - 100      NaN
#
#                          region  \
# 692     Belize, Central America
# 690         Nova Scotia, Canada
# 689     Panama, Central America
# 693         Nova Scotia, Canada
# 688  Nicaragua, Central America
# ..                          ...
# 691    British Columbia, Canada
# 694  Mississippi, United States
# 695      Florida, United States
# 696     Belize, Central America
# 697        Maine, United States
#
#                                                   tags scrape_date
# 692                                       Ocean Island  2021-07-27
# 690      Islands with Beaches,Lake Island,Mainland Lot  2021-07-27
# 689                                       Ocean Island  2021-07-27
# 693                              Ocean Island,Seasonal  2021-07-27
# 688                         Lake Island,Mainland Power  2021-07-27
# ..                                                 ...         ...
# 691                       Lake Island,Income Potential  2021-07-27
# 694                                       Ocean Island  2021-07-27
# 695  Islands with Beaches,Large Acreage,Ocean Islan...  2021-07-27
# 696  Islands with Beaches,Large Acreage,Income Prod...  2021-07-27
# 697        Islands with Beaches,Large Acreage,Turn Key  2021-07-27
#
# [698 rows x 7 columns]

# %%
island_df = island_df.dropna(subset = ['price'])

# %%
island_df.to_csv('island_scrape_for_viz.csv')
